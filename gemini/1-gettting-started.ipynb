# %%
import os
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain how AI works",
)

print(response.text)
# Out:
# Okay, let's break down how Artificial Intelligence (AI) works. It's a broad field, so I'll cover the fundamental concepts and then touch upon some of the core techniques.
#
# **Core Idea: Enabling Machines to Mimic Human Intelligence**
#
# At its heart, AI aims to create computer systems that can perform tasks that typically require human intelligence.  This includes things like:
#
# *   **Learning:**  Acquiring information and rules for using it.
# *   **Reasoning:**  Using rules to reach conclusions (making decisions, solving problems).
# *   **Problem Solving:**  Finding solutions to complex issues.
# *   **Perception:**  Interpreting sensory data (like images, sound, or text).
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
#
# **Key Components and Approaches**
#
# AI isn't a single technology, but rather a collection of methods. Here are some of the most important:
#
# 1.  **Machine Learning (ML): The Foundation of Modern AI**
#
#     *   **What it is:** Machine learning is a type of AI that allows systems to learn from data without being explicitly programmed. Instead of writing specific rules, you feed the system data and it figures out the patterns.  This is how most AI breakthroughs have happened in the last decade.
#
#     *   **How it works:** ML algorithms are trained on large datasets.  During training, they adjust their internal parameters to improve their performance on a specific task (like predicting whether an email is spam or recognizing a cat in an image).
#
#     *   **Types of Machine Learning:**
#
#         *   **Supervised Learning:** The algorithm is trained on a labeled dataset, meaning each piece of data has a "correct answer."  The algorithm learns to map inputs to outputs.  Examples:
#             *   *Classification:* Categorizing data into classes (e.g., spam/not spam, cat/dog/bird).
#             *   *Regression:* Predicting a continuous value (e.g., predicting house prices).
#
#         *   **Unsupervised Learning:** The algorithm is trained on an unlabeled dataset, and it has to find patterns and structures on its own. Examples:
#             *   *Clustering:* Grouping similar data points together (e.g., segmenting customers based on their behavior).
#             *   *Dimensionality Reduction:* Reducing the number of variables in a dataset while preserving important information.
#
#         *   **Reinforcement Learning:** The algorithm learns by interacting with an environment and receiving rewards or penalties for its actions. It tries to maximize its cumulative reward.  Think of training a dog: you give it treats for good behavior.  Examples:
#             *   *Game playing:* Training AI to play games like Go or chess.
#             *   *Robotics:* Training robots to perform tasks.
#
# 2.  **Neural Networks and Deep Learning**
#
#     *   **What they are:**  Neural networks are a type of machine learning algorithm inspired by the structure of the human brain.  They consist of interconnected nodes (neurons) organized in layers.  "Deep learning" refers to neural networks with many layers (hence, "deep").
#
#     *   **How they work:**  Data is fed into the input layer, and each neuron performs a simple calculation on its inputs and passes the result to the next layer.  The connections between neurons have weights that are adjusted during training to improve the network's performance.  Deep learning networks can automatically learn complex features from raw data, which is why they're so effective for tasks like image recognition and natural language processing.
#
#     *   **Types of Neural Networks:**
#         *   *Convolutional Neural Networks (CNNs):*  Excellent for image and video processing.
#         *   *Recurrent Neural Networks (RNNs):*  Designed for sequential data like text and time series.
#         *   *Transformers:*  A more recent architecture that has revolutionized natural language processing. (used in ChatGPT and similar models)
#
# 3.  **Natural Language Processing (NLP)**
#
#     *   **What it is:** A field of AI focused on enabling computers to understand, interpret, and generate human language.
#
#     *   **How it works:** NLP involves a range of techniques, including:
#         *   *Tokenization:* Breaking text into individual words or units.
#         *   *Part-of-speech tagging:* Identifying the grammatical role of each word (noun, verb, adjective, etc.).
#         *   *Named entity recognition:* Identifying and classifying named entities (people, organizations, locations).
#         *   *Sentiment analysis:* Determining the emotional tone of text (positive, negative, neutral).
#         *   *Machine translation:* Translating text from one language to another.
#         *   *Text generation:* Creating new text, such as summaries, articles, or stories.
#
# 4.  **Knowledge Representation and Reasoning**
#
#     *   **What it is:**  This area deals with how to represent knowledge in a way that computers can understand and use to reason and make decisions.
#
#     *   **How it works:**
#         *   *Rule-based systems:*  Use a set of "if-then" rules to make decisions.
#         *   *Semantic networks:* Represent knowledge as a graph of concepts and relationships.
#         *   *Ontologies:* Formal representations of knowledge within a specific domain.
#         *   *Logic programming:* Uses logical statements to represent knowledge and perform reasoning.
#
# 5.  **Computer Vision**
#
#     *   **What it is:** Enables computers to "see" and interpret images and videos.
#
#     *   **How it works:**
#         *   *Image recognition:* Identifying objects in images.
#         *   *Object detection:* Locating objects within an image.
#         *   *Image segmentation:* Dividing an image into regions based on different objects or features.
#         *   *Facial recognition:* Identifying faces in images or videos.
#
# **The AI Development Process (Simplified)**
#
# 1.  **Define the Problem:** Clearly state the problem you're trying to solve with AI.
# 2.  **Gather Data:** Collect a large and relevant dataset for training the AI model.  Data quality is *critical*.
# 3.  **Choose an Algorithm/Model:** Select the appropriate AI technique based on the problem and data.
# 4.  **Train the Model:** Feed the data to the algorithm and let it learn.
# 5.  **Evaluate the Model:** Test the model on a separate dataset to assess its performance.
# 6.  **Tune and Refine:** Adjust the model's parameters and retrain it until it meets your desired performance.
# 7.  **Deploy and Monitor:** Put the model into production and continuously monitor its performance.
#
# **Important Considerations**
#
# *   **Bias:**  AI models can inherit biases from the data they are trained on, leading to unfair or discriminatory outcomes.  It's crucial to address bias throughout the development process.
# *   **Explainability:** Understanding why an AI model makes a particular decision is important, especially in sensitive applications.  "Explainable AI" (XAI) is a growing field focused on making AI models more transparent.
# *   **Ethics:**  AI raises important ethical considerations about privacy, security, and the potential impact on society.
#
# **In summary, AI works by using algorithms and data to mimic human intelligence, enabling machines to learn, reason, solve problems, and understand natural language.** The specific techniques used depend on the problem being addressed, but machine learning, particularly deep learning, is the dominant approach in many modern AI applications.
