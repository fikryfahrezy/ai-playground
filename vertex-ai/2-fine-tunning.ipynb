# %%
import time
import os

import vertexai
from vertexai.tuning import sft
from dotenv import load_dotenv

load_dotenv()

vertexai.init(project=os.getenv("GOOGLE_CLOUD_PROJECT"), location="us-central1")

sft_tuning_job = sft.train(
    source_model="gemini-2.0-flash-001",
    # 1.5 and 2.0 models use the same JSONL format
    train_dataset="gs://trying-out-fine-tune/sft_train_data.jsonl",
)

# Polling for job completion
while not sft_tuning_job.has_ended:
    time.sleep(60)
    sft_tuning_job.refresh()

print(sft_tuning_job.tuned_model_name)
print(sft_tuning_job.tuned_model_endpoint_name)
print(sft_tuning_job.experiment)
# Out:
# Creating SupervisedTuningJob
# SupervisedTuningJob created. Resource name: projects/42754571085/locations/us-central1/tuningJobs/1909911912888401920
# To use this SupervisedTuningJob in another session:
# tuning_job = sft.SupervisedTuningJob('projects/42754571085/locations/us-central1/tuningJobs/1909911912888401920')
# View Tuning Job:
# https://console.cloud.google.com/vertex-ai/generative/language/locations/us-central1/tuning/tuningJob/1909911912888401920?project=42754571085
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-61732350-c3c4-4064-886d-f8801ec006a2" href="#view-view-vertex-resource-61732350-c3c4-4064-886d-f8801ec006a2">
#           <span class="material-icons view-vertex-icon">tune</span>
#           <span>View Tuning Job</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-61732350-c3c4-4064-886d-f8801ec006a2');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-central1/tuning/tuningJob/1909911912888401920?project=42754571085');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-central1/tuning/tuningJob/1909911912888401920?project=42754571085', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-42343cb3-9318-4f9d-835f-ce8737dd0e8d" href="#view-view-vertex-resource-42343cb3-9318-4f9d-835f-ce8737dd0e8d">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-42343cb3-9318-4f9d-835f-ce8737dd0e8d');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/tuning-experiment-20250406191940750161/runs?project=gen-lang-client-0056310587');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/tuning-experiment-20250406191940750161/runs?project=gen-lang-client-0056310587', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# projects/42754571085/locations/us-central1/models/3709520235162763264@1
# projects/42754571085/locations/us-central1/endpoints/3442690753334083584
# <google.cloud.aiplatform.metadata.experiment_resources.Experiment object at 0x1227d6850>

# %%
from vertexai.generative_models import GenerativeModel

tuned_model = GenerativeModel(sft_tuning_job.tuned_model_endpoint_name)
print(sft_tuning_job.tuned_model_endpoint_name)
print(tuned_model.generate_content("What is the goal of therapy with antiviral drugs?"))
# Out:
# projects/42754571085/locations/us-central1/endpoints/3442690753334083584
# candidates {
#   content {
#     role: "model"
#     parts {
#       text: "Treat active infections, reducing viral load. Prevent the spread of infection to others. Delay the progression from HIV infection to AIDS and the development of opportunistic diseases. Minimize morbidity and mortality."
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -1.1653359731038411
# }
# usage_metadata {
#   prompt_token_count: 10
#   candidates_token_count: 36
#   total_token_count: 46
# }
